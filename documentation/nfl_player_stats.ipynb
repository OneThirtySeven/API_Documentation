# %% [markdown]
# [back](NFL.md)
#
# <h3 style="margin-bottom: 0px; font-weight: bold;">Player Stats</h3>
#
# - Returns Player Stats on a per game basis
#
# ***
# GET: **https://nfl.onethirtyseven.io/player_box**<br>
#
# - Requires API Key<br>
#     - To get your OneThirtySeven API Key follow the [instructions](GET_API_KEY.md):
# - Optional Parameters
#     - GameID
# ***

# %%
pd.set_option('display.max_rows', None)

import requests
import pandas as pd
import json

# Replace with your personal API_KEY
API_KEY = '3dc348e87a2988b1b90f5137313d436f57e258bceb9b4e7f643a6fb8fa96b77e'

# Make get request
res = requests.get('https://nfl.onethirtyseven.io/player_box?GameId=803098376', headers={'api_key': API_KEY})

# Extract payload: Decode binary -> Convert the JSON str to dict() -> Convert dict to DataFrame
Player_Stats = pd.DataFrame.from_dict(json.loads(res.content.decode('utf-8')))

# Display Results
Player_Stats.head(5)
# Out:
#             Player Team  Opp  isHome  Season Season_Type  Pass_Completions  \
# 0     Alonzo Davis  TEN  CHI     0.0    2023  Pre-Season               NaN
# 1  Anthony Kendall  TEN  CHI     0.0    2023  Pre-Season               NaN
# 2     Armani Marsh  TEN  CHI     0.0    2023  Pre-Season               NaN
# 3      Ben Niemann  TEN  CHI     0.0    2023  Pre-Season               NaN
# 4     Caleb Murphy  TEN  CHI     0.0    2023  Pre-Season               NaN
#
#    Pass_Attempts  Pass_Yards  Pass_Avg  ...  Punt_Yards  Punt_Avg  \
# 0            NaN         NaN       NaN  ...         NaN       NaN
# 1            NaN         NaN       NaN  ...         NaN       NaN
# 2            NaN         NaN       NaN  ...         NaN       NaN
# 3            NaN         NaN       NaN  ...         NaN       NaN
# 4            NaN         NaN       NaN  ...         NaN       NaN
#
#    Punt_Touchback  Punt_Inside_20  Punt_Long  Game_Status    Game_Id  Team_Id  \
# 0             NaN             NaN        NaN        Final  803098376     1574
# 1             NaN             NaN        NaN        Final  803098376     1574
# 2             NaN             NaN        NaN        Final  803098376     1574
# 3             NaN             NaN        NaN        Final  803098376     1574
# 4             NaN             NaN        NaN        Final  803098376     1574
#
#    Opp_Id  Player_Id
# 0    1560    8503590
# 1    1560   10288112
# 2    1560    8491862
# 3    1560    6282840
# 4    1560    9824532
#
# [5 rows x 67 columns]

# %%
# Out:
#             Player Team  Opp  isHome  Season Season_Type  Pass_Completions  \
# 0     Alonzo Davis  TEN  CHI     0.0    2023  Pre-Season               NaN
# 1  Anthony Kendall  TEN  CHI     0.0    2023  Pre-Season               NaN
# 2     Armani Marsh  TEN  CHI     0.0    2023  Pre-Season               NaN
# 3      Ben Niemann  TEN  CHI     0.0    2023  Pre-Season               NaN
# 4     Caleb Murphy  TEN  CHI     0.0    2023  Pre-Season               NaN
#
#    Pass_Attempts  Pass_Yards  Pass_Avg  ...  Punt_Yards  Punt_Avg  \
# 0            NaN         NaN       NaN  ...         NaN       NaN
# 1            NaN         NaN       NaN  ...         NaN       NaN
# 2            NaN         NaN       NaN  ...         NaN       NaN
# 3            NaN         NaN       NaN  ...         NaN       NaN
# 4            NaN         NaN       NaN  ...         NaN       NaN
#
#    Punt_Touchback  Punt_Inside_20  Punt_Long  Game_Status    Game_Id  Team_Id  \
# 0             NaN             NaN        NaN        Final  803098376     1574
# 1             NaN             NaN        NaN        Final  803098376     1574
# 2             NaN             NaN        NaN        Final  803098376     1574
# 3             NaN             NaN        NaN        Final  803098376     1574
# 4             NaN             NaN        NaN        Final  803098376     1574
#
#    Opp_Id  Player_Id
# 0    1560    8503590
# 1    1560   10288112
# 2    1560    8491862
# 3    1560    6282840
# 4    1560    9824532
#
# [5 rows x 67 columns]
