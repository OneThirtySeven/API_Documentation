# %% [markdown]
# [back](NFL.md)
#
# <h3 style="margin-bottom: 0px; font-weight: bold;">Player Stats</h3>
#
# - Returns Player Stats on a per game basis
#
# ***
# GET: **https://nfl.onethirtyseven.io/player_box**<br>
#
# - Requires API Key<br>
#     - To get your OneThirtySeven API Key follow the [instructions](GET_API_KEY.md):
# - Optional Parameters
#     - GameID
# ***

# %%
import requests
import pandas as pd
import json

# Replace with your personal API_KEY
API_KEY = '3dc348e87a2988b1b90f5137313d436f57e258bceb9b4e7f643a6fb8fa96b77e'

# Make get request
res = requests.get('https://nfl.onethirtyseven.io/player_box?GameId=803096036', headers={'api_key': API_KEY})

# Extract payload: Decode binary -> Convert the JSON str to dict() -> Convert dict to DataFrame
Player_Stats = pd.DataFrame.from_dict(json.loads(res.content.decode('utf-8')))

# Display Top 5 by Passing_Yards
pd.set_option('display.max_columns', None)
Player_Stats.sort_values('Pass_Yards', ascending=False).head(2)
# Out:
#           Player Team  Opp  isHome  Season     Season_Type  Pass_Completions  \
# 46   Jalen Hurts  PHI  NYG     1.0    2023  Regular-Season              24.0
# 28  Tyrod Taylor  NYG  PHI     0.0    2023  Regular-Season               7.0
#
#     Pass_Attempts  Pass_Yards  Pass_Avg  Pass_TD  Pass_INT  Sacks_Against  \
# 46           38.0       301.0      7.92      1.0       1.0            1.0
# 28           16.0       133.0      8.31      1.0       1.0            0.0
#
#     Sacks_Against_Yards  Passer_Rating  Rush_Attempts  Rush_Yards  Rush_Avg  \
# 46                  6.0           85.5            8.0        34.0      4.25
# 28                  0.0           68.0            2.0        21.0     10.50
#
#     Rush_TD  Rush_Longest  Receptions  Receiving_Yards  Receiving_Avg  \
# 46      1.0          16.0         NaN              NaN            NaN
# 28      0.0          15.0         NaN              NaN            NaN
#
#     Receiving_TD  Receiving_Long  Receiving_Targets  Fumbles  Fumbles_Lost  \
# 46           NaN             NaN                NaN      1.0           0.0
# 28           NaN             NaN                NaN      NaN           NaN
#
#     Fumbles_Recovered  Tackles  Tackles_Solo  Sacks  Tackles_for_Loss  \
# 46                1.0      NaN           NaN    NaN               NaN
# 28                NaN      NaN           NaN    NaN               NaN
#
#     Passes_Defended  QB_Hits  Defensive_TD  Interceptions  Int_Return_Yards  \
# 46              NaN      NaN           NaN            NaN               NaN
# 28              NaN      NaN           NaN            NaN               NaN
#
#     Int_TD  Kickoff_Returns  Kickoff_Return_Yards  Kickoff_Return_Avg  \
# 46     NaN              NaN                   NaN                 NaN
# 28     NaN              NaN                   NaN                 NaN
#
#     Kickoff_Return_Long  Kickoff_Return_TD  Punt_Returns  Punt_Return_Yards  \
# 46                  NaN                NaN           NaN                NaN
# 28                  NaN                NaN           NaN                NaN
#
#     Punt_Return_Avg  Punt_Return_Long  Punt_Return_TD  Field_Goal_Made  \
# 46              NaN               NaN             NaN              NaN
# 28              NaN               NaN             NaN              NaN
#
#     Field_Goal_Attempts  Field_Goal_Percent  Field_Goal_Long  \
# 46                  NaN                 NaN              NaN
# 28                  NaN                 NaN              NaN
#
#     Extra_Point_Made  Extra_Point_Attempts  Kicker_Points  Punt_Attempts  \
# 46               NaN                   NaN            NaN            NaN
# 28               NaN                   NaN            NaN            NaN
#
#     Punt_Yards  Punt_Avg  Punt_Touchback  Punt_Inside_20  Punt_Long  \
# 46         NaN       NaN             NaN             NaN        NaN
# 28         NaN       NaN             NaN             NaN        NaN
#
#    Game_Status    Game_Id Team_Id Opp_Id Player_Id
# 46       Final  803096036    1596   1592   8082984
# 28       Final  803096036    1592   1596     29880
