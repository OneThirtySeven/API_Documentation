# %%
import requests
import pandas as pd
import json

# %% [markdown]
# #### First set API_KEY
# To get your OneThirtySeven API Key follow the [instructions](GET_API_KEY.md):

# %%
API_KEY = '3dc348e87a2988b1b90f5137313d436f57e258bceb9b4e7f643a6fb8fa96b77e'

# %%
res = requests.get('https://nfl.onethirtyseven.io/teams', headers={'api_key': API_KEY})
Game_Summaries = json.loads(res.content.decode('utf8'))
pd.DataFrame.from_dict(Game_Summaries)
# Out:
#    Short_Name Conference Division           City   Team_Name
# 0         BUF        AFC     East        Buffalo       Bills
# 1         MIA        AFC     East          Miami    Dolphins
# 2         NYJ        AFC     East       New York        Jets
# 3          NE        AFC     East    New England    Patriots
# 4         CLE        AFC    North      Cleveland      Browns
# 5         BAL        AFC    North      Baltimore      Ravens
# 6         PIT        AFC    North     Pittsburgh    Steelers
# 7         CIN        AFC    North     Cincinnati     Bengals
# 8         HOU        AFC    South        Houston      Texans
# 9         IND        AFC    South   Indianapolis       Colts
# 10        TEN        AFC    South      Tennessee      Titans
# 11        JAX        AFC    South   Jacksonville     Jaguars
# 12         LV        AFC     West      Las Vegas     Raiders
# 13        DEN        AFC     West         Denver     Broncos
# 14        LAC        AFC     West    Los Angeles    Chargers
# 15         KC        AFC     West    Kansas City      Chiefs
# 16        NYG        NFC     East       New York      Giants
# 17        WAS        NFC     East     Washington  Commanders
# 18        PHI        NFC     East   Philadelphia      Eagles
# 19        DAL        NFC     East         Dallas     Cowboys
# 20        CHI        NFC    North        Chicago       Bears
# 21        DET        NFC    North        Detroit       Lions
# 22         GB        NFC    North      Green Bay     Packers
# 23        MIN        NFC    North      Minnesota     Vikings
# 24        ATL        NFC    South        Atlanta     Falcons
# 25        CAR        NFC    South       Carolina    Panthers
# 26         TB        NFC    South      Tampa Bay  Buccaneers
# 27         NO        NFC    South    New Orleans      Saints
# 28         SF        NFC     West  San Francisco       49ers
# 29        ARI        NFC     West        Arizona   Cardinals
# 30        LAR        NFC     West    Los Angeles        Rams
# 31        SEA        NFC     West        Seattle    Seahawks
