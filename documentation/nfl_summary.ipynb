# %%
import requests
import pandas as pd
import json

# %% [markdown]
# #### First set API_KEY
# To get your OneThirtySeven API Key follow the [instructions](GET_API_KEY.md):

# %%
API_KEY = '3dc348e87a2988b1b90f5137313d436f57e258bceb9b4e7f643a6fb8fa96b77e'

# %%
res = requests.get('https://nfl.onethirtyseven.io/summary', headers={'api_key': API_KEY})
Game_Summaries = pd.DataFrame.from_dict(json.loads(res.content.decode('utf-8')))
Game_Summaries.head(5)
# Out:
#   Team  Opp   Game_Date Game_Time Timezone  isHome  Season Season_Type  \
# 0  CLE  NYJ  2023-08-04     00:00      UTC     1.0    2023  Pre-Season
# 1  NYJ  CLE  2023-08-04     00:00      UTC     0.0    2023  Pre-Season
# 2  WSH  BAL  2023-08-22     00:00      UTC     1.0    2023  Pre-Season
# 3  BAL  WSH  2023-08-22     00:00      UTC     0.0    2023  Pre-Season
# 4  PHI  IND  2023-08-25     00:00      UTC     1.0    2023  Pre-Season
#
#   Playoff_Round  Quarters  ...     Back_Judge    Line_Judge           Umpire  \
# 0          None         4  ...           None          None             None
# 1          None         4  ...           None          None             None
# 2          None         4  ...  Tony Josselyn    Max Causey   Barry Anderson
# 3          None         4  ...  Tony Josselyn    Max Causey   Barry Anderson
# 4          None         4  ...    Greg Wilson  Greg Bradley  James Carter II
#
#           Referee        Field_Judge        Side_Judge      Game_Id  Team_Id  \
# 0            None               None              None  803096862.0   1564.0
# 1            None               None              None  803096862.0   1594.0
# 2  Ronald Torbert       Ryan Dickson  Keith Washington  803096864.0   1610.0
# 3  Ronald Torbert       Ryan Dickson  Keith Washington  803096864.0   1620.0
# 4     Clay Martin  Alonzo Ramsey III     Dave Hawkshaw  803096866.0   1596.0
#
#    Opp_Id  Game_Status
# 0  1594.0        Final
# 1  1564.0        Final
# 2  1620.0        Final
# 3  1610.0        Final
# 4  1576.0        Final
#
# [5 rows x 101 columns]
